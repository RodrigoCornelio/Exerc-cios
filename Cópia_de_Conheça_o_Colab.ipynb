# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoCornelio/Exerc-cios/blob/main/C%C3%B3pia_de_Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


media = 4500
desvio_padrao = 1500
tamanho = 1000
min_salario = 1200
max_salario = 8000


salarios = np.random.normal(loc=media, scale=desvio_padrao, size=tamanho)
salarios = np.clip(salarios, min_salario, max_salario)
salarios = np.round(salarios, 2)


print("Lista de salários simulados (primeiros 20 valores):")
print(salarios[:20])


print("\nEstatísticas:")
print(f"Média: R${np.mean(salarios):.2f}")
print(f"Mediana: R${np.median(salarios):.2f}")
print(f"Desvio padrão: R${np.std(salarios):.2f}")
print(f"Mínimo: R${np.min(salarios):.2f}")
print(f"Máximo: R${np.max(salarios):.2f}")

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):

        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:

                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

def heapify(arr, n, i):
    maior = i
    esq = 2 * i + 1
    dir = 2 * i + 2


    if esq < n and arr[i] < arr[esq]:
        maior = esq


    if dir < n and arr[maior] < arr[dir]:
        maior = dir


    if maior != i:
        arr[i], arr[maior] = arr[maior], arr[i]
        heapify(arr, n, maior)

def heap_sort(arr):
    n = len(arr)


    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)


    for i in range(n-1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)
    return arr

def merge_sort(arr):
    if len(arr) > 1:
        meio = len(arr) // 2
        esquerda = arr[:meio]
        direita = arr[meio:]


        merge_sort(esquerda)
        merge_sort(direita)


        i = j = k = 0

        while i < len(esquerda) and j < len(direita):
            if esquerda[i] < direita[j]:
                arr[k] = esquerda[i]
                i += 1
            else:
                arr[k] = direita[j]
                j += 1
            k += 1


        while i < len(esquerda):
            arr[k] = esquerda[i]
            i += 1
            k += 1

        while j < len(direita):
            arr[k] = direita[j]
            j += 1
            k += 1
    return arr

import numpy as np


np.random.seed(42)
salarios = np.random.normal(loc=4500, scale=1500, size=20)
salarios = np.clip(salarios, 1200, 8000)
salarios = np.round(salarios, 2)
lista_salarios = list(salarios)

print("Lista original:")
print(lista_salarios)

print("\nBubble Sort:")
print(bubble_sort(lista_salarios.copy()))

print("\nMerge Sort:")
print(merge_sort(lista_salarios.copy()))

print("\nHeap Sort:")
print(heap_sort(lista_salarios.copy()))

import time
import numpy as np
from copy import deepcopy


def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

def merge_sort(arr):
    if len(arr) > 1:
        meio = len(arr) // 2
        esquerda = arr[:meio]
        direita = arr[meio:]
        merge_sort(esquerda)
        merge_sort(direita)
        i = j = k = 0
        while i < len(esquerda) and j < len(direita):
            if esquerda[i] < direita[j]:
                arr[k] = esquerda[i]
                i += 1
            else:
                arr[k] = direita[j]
                j += 1
            k += 1
        while i < len(esquerda):
            arr[k] = esquerda[i]
            i += 1
            k += 1
        while j < len(direita):
            arr[k] = direita[j]
            j += 1
            k += 1
    return arr

def heapify(arr, n, i):
    maior = i
    esq = 2 * i + 1
    dir = 2 * i + 2
    if esq < n and arr[i] < arr[esq]:
        maior = esq
    if dir < n and arr[maior] < arr[dir]:
        maior = dir
    if maior != i:
        arr[i], arr[maior] = arr[maior], arr[i]
        heapify(arr, n, maior)

def heap_sort(arr):
    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
    for i in range(n-1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)
    return arr


np.random.seed(42)
salarios = np.random.normal(loc=4500, scale=1500, size=1000)
salarios = np.clip(salarios, 1200, 8000)
salarios = np.round(salarios, 2)
lista_salarios = list(salarios)


cenarios = {
    "Lista aleatória": lista_salarios,
    "Lista ordenada": sorted(lista_salarios),
    "Lista inversamente ordenada": sorted(lista_salarios, reverse=True),
    "Lista com muitos duplicados": [np.random.choice([2000, 3000, 4000, 5000, 6000]) for _ in range(1000)]
}


algoritmos = {
    "Bubble Sort": bubble_sort,
    "Merge Sort": merge_sort,
    "Heap Sort": heap_sort
}

resultados = {}

for nome_cenario, dados in cenarios.items():
    print(f"\n--- {nome_cenario} ---")
    resultados[nome_cenario] = {}

    for nome_algoritmo, algoritmo in algoritmos.items():
        copia_dados = deepcopy(dados)

        inicio = time.time()
        algoritmo(copia_dados)
        tempo_execucao = time.time() - inicio

        resultados[nome_cenario][nome_algoritmo] = tempo_execucao
        print(f"{nome_algoritmo}: {tempo_execucao:.5f} segundos")


print("\nRESUMO DOS TEMPOS DE EXECUÇÃO (segundos):")
print("{:<25} {:<15} {:<15} {:<15}".format(
    "Cenário", "Bubble Sort", "Merge Sort", "Heap Sort"))

for cenario, tempos in resultados.items():
    print("{:<25} {:<15.5f} {:<15.5f} {:<15.5f}".format(
        cenario,
        tempos["Bubble Sort"],
        tempos["Merge Sort"],
        tempos["Heap Sort"]))
# Out:
# Lista de salários simulados (primeiros 20 valores):
# [6698.47 4161.34 4601.29 2362.88 3683.43 4666.38 2773.51 5063.55 3599.04
#  4062.46 3597.44 7278.42 4479.75 2913.43 5733.82 2668.73 4813.3  1560.49
#  2507.72 4795.29]
#
# Estatísticas:
# Média: R$4545.71
# Mediana: R$4560.63
# Desvio padrão: R$1438.20
# Mínimo: R$1200.00
# Máximo: R$8000.00
# Lista original:
# [np.float64(5245.07), np.float64(4292.6), np.float64(5471.53), np.float64(6784.54), np.float64(4148.77), np.float64(4148.79), np.float64(6868.82), np.float64(5651.15), np.float64(3795.79), np.float64(5313.84), np.float64(3804.87), np.float64(3801.41), np.float64(4862.94), np.float64(1630.08), np.float64(1912.62), np.float64(3656.57), np.float64(2980.75), np.float64(4971.37), np.float64(3137.96), np.float64(2381.54)]
#
# Bubble Sort:
# ...
